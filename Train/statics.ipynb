# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/media/prince/5A4E832F4E83034D/Movie recomender/Train_v2/final-cleaned-data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            4803 non-null   int64
#  1   original_language     4803 non-null   object
#  2   overview              4800 non-null   object
#  3   popularity            4803 non-null   float64
#  4   runtime               4803 non-null   float64
#  5   tagline               3959 non-null   object
#  6   title                 4803 non-null   object
#  7   vote_average          4803 non-null   float64
#  8   vote_count            4803 non-null   float64
#  9   genre_names           4803 non-null   object
#  10  keywords_names        4803 non-null   object
#  11  companies_categories  4803 non-null   object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 450.4+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_cols = ['popularity', 'runtime', 'vote_average', 'vote_count']

# 1. HISTOGRAMS
for col in num_cols:
    plt.hist(df[col], bins=20)
    plt.title(f"Distribution of {col}")
    plt.show()

# 2. BOXPLOTS
for col in num_cols:
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# 3. CORRELATION HEATMAP
plt.figure(figsize=(5,4))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation")
plt.show()

# Drop useless index column if still present
df = df.drop(columns=['Unnamed: 0'])
